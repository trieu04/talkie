# %% [markdown]
# # Talkie Colab Worker
#
# Run this notebook in Google Colab with a GPU runtime enabled.

# %%
# !pip install faster-whisper httpx soundfile torch torchaudio silero-vad

# %%
from google.colab import drive

MOUNT_DRIVE = False
if MOUNT_DRIVE:
    drive.mount('/content/drive')

# %%
# %cd /content
# !rm -rf talkie
# !git clone <repo-url> talkie
# %cd /content/talkie/colab-worker

# %%
import os

os.environ['TALKIE_SERVER_URL'] = 'https://your-server-url'
os.environ['WORKER_ID'] = 'colab-worker-1'

# %%
# !python -m worker.main
